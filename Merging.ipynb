# %%
import os,numpy as np,pandas as pd

# %%
os.chdir("E:\Machine learning course\Raw data\merge user")

# %%
us_us = pd.read_excel("user_usage.xlsx")

# %%
us_us.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792

# %%
us_dv = pd.read_excel("user_device.xlsx")

# %%
us_dv.head()
# Out:
#    use_id  user_id platform  platform_version     device  use_type_id
# 0   22782    26980      ios              10.2  iPhone7,2            2
# 1   22783    29628  android               6.0    Nexus 5            3
# 2   22784    28473  android               5.1   SM-G903F            1
# 3   22785    15200      ios              10.2  iPhone7,2            3
# 4   22786    28239  android               6.0  ONE E1003            1

# %%
an_dv = pd.read_csv("android_devices.csv")

# %%
an_dv.tail()
# Out:
#       Retail Branding Marketing Name       Device        Model
# 14541           pendo    PNDPP44QC10  PNDPP44QC10  PNDPP44QC10
# 14542           pendo     PNDPP44QC7   PNDPP44QC7   PNDPP44QC7
# 14543      sugar_aums         QPOINT        QPI-1        QPI-1
# 14544       tecmobile       OmnisOne     OmnisOne    Omnis One
# 14545           ucall          EASY1        EASY1        EASY1

# %% [markdown]
# ## Inner join

# %%
data = pd.merge(us_us,us_dv,on="use_id",how='inner')

# %%
data
# Out:
#      outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                      21.97                    4.82     1557.33   22787
# 1                    1710.08                  136.88     7267.55   22788
# 2                    1710.08                  136.88     7267.55   22789
# 3                      94.46                   35.17      519.12   22790
# 4                      71.59                   79.26     1557.33   22792
# ..                       ...                     ...         ...     ...
# 154                   198.59                   90.49     5191.12   23043
# 155                   198.59                   90.49     3114.67   23044
# 156                   106.65                   82.13     5191.12   23046
# 157                   344.53                   20.53      519.12   23049
# 158                    42.75                   46.83     5191.12   23053
#
#      user_id platform  platform_version                  device  use_type_id
# ...

# %%
us_us.shape
# Out:
# (240, 4)

# %%
us_dv.shape
# Out:
# (272, 6)

# %%
data.shape
# Out:
# (159, 9)

# %% [markdown]
# ## Left Join

# %%
data2 = pd.merge(us_us,us_dv,on="use_id",how='left')

# %%
data2.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
#
#    user_id platform  platform_version    device  use_type_id
# 0  12921.0  android               4.3  GT-I9505          1.0
# 1  28714.0  android               6.0  SM-G930F          1.0
# 2  28714.0  android               6.0  SM-G930F          1.0
# 3  29592.0  android               5.1     D2303          1.0
# 4  28217.0  android               5.1  SM-G361F          1.0

# %%
data2.shape
# Out:
# (240, 9)

# %% [markdown]
# ## Right Join

# %%
data3 = pd.merge(us_us,us_dv,on="use_id",how='right')

# %%
data3.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                      NaN                     NaN         NaN   22782
# 1                      NaN                     NaN         NaN   22783
# 2                      NaN                     NaN         NaN   22784
# 3                      NaN                     NaN         NaN   22785
# 4                      NaN                     NaN         NaN   22786
#
#    user_id platform  platform_version     device  use_type_id
# 0    26980      ios              10.2  iPhone7,2            2
# 1    29628  android               6.0    Nexus 5            3
# 2    28473  android               5.1   SM-G903F            1
# 3    15200      ios              10.2  iPhone7,2            3
# 4    28239  android               6.0  ONE E1003            1

# %%
data3.shape
# Out:
# (272, 9)

# %% [markdown]
# ## Full join

# %%
data4 = pd.merge(us_us,us_dv,on="use_id",how='outer')

# %%
data4.head(20)
# Out:
#     outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                     21.97                    4.82     1557.33   22787
# 1                   1710.08                  136.88     7267.55   22788
# 2                   1710.08                  136.88     7267.55   22789
# 3                     94.46                   35.17      519.12   22790
# 4                     71.59                   79.26     1557.33   22792
# 5                     71.59                   79.26     1557.33   22793
# 6                     71.59                   79.26      519.12   22794
# 7                     71.59                   79.26      519.12   22795
# 8                     30.92                   22.77     3114.67   22799
# 9                     69.80                   14.70    25955.55   22801
# 10                   554.41                  150.06     3114.67   22804
# 11                   189.10                   24.08      519.12   22805
# ...

# %%
data4.shape
# Out:
# (353, 9)

# %% [markdown]
# ##  If the column names are different in the two dataframes

# %%
us_dv.head()
# Out:
#    use_id  user_id platform  platform_version     device  use_type_id
# 0   22782    26980      ios              10.2  iPhone7,2            2
# 1   22783    29628  android               6.0    Nexus 5            3
# 2   22784    28473  android               5.1   SM-G903F            1
# 3   22785    15200      ios              10.2  iPhone7,2            3
# 4   22786    28239  android               6.0  ONE E1003            1

# %%
an_dv.head()
# Out:
#   Retail Branding Marketing Name    Device                      Model
# 0             NaN            NaN    AD681H  Smartfren Andromax AD681H
# 1             NaN            NaN     FJL21                      FJL21
# 2             NaN            NaN       T31              Panasonic T31
# 3             NaN            NaN  hws7721g         MediaPad 7 Youth 2
# 4              3Q        OC1020A   OC1020A                    OC1020A

# %%
all_data = pd.merge(us_dv,an_dv,left_on="device", right_on= "Model", how='inner')

# %%
all_data.head()
# Out:
#    use_id  user_id platform  platform_version     device  use_type_id  \
# 0   22783    29628  android               6.0    Nexus 5            3
# 1   22784    28473  android               5.1   SM-G903F            1
# 2   22971    29696  android               5.1   SM-G903F            1
# 3   22972    29696  android               5.1   SM-G903F            1
# 4   22786    28239  android               6.0  ONE E1003            1
#
#   Retail Branding Marketing Name      Device      Model
# 0             LGE        Nexus 5  hammerhead    Nexus 5
# 1         Samsung  Galaxy S5 Neo    s5neolte   SM-G903F
# 2         Samsung  Galaxy S5 Neo    s5neolte   SM-G903F
# 3         Samsung  Galaxy S5 Neo    s5neolte   SM-G903F
# 4         OnePlus        OnePlus     OnePlus  ONE E1003

# %%
all_data.shape
# Out:
# (232, 10)

# %%
all_data = pd.merge(us_us,us_dv,on="use_id",how='inner').merge(an_dv, left_on="device", right_on= "Model", how='inner')

# %%
all_data.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                    69.80                   14.70    25955.55   22801
# 2                   249.26                  253.22     1557.33   22875
# 3                   249.26                  253.22     1557.33   22876
# 4                    83.46                  114.06     3114.67   22880
#
#    user_id platform  platform_version    device  use_type_id Retail Branding  \
# 0    12921  android               4.3  GT-I9505            1         Samsung
# 1    10976  android               4.4  GT-I9505            1         Samsung
# 2    27593  android               5.0  GT-I9505            1         Samsung
# 3    27593  android               5.0  GT-I9505            1         Samsung
# 4    29366  android               5.0  GT-I9505            1         Samsung
#
#   Marketing Name Device     Model
# 0      Galaxy S4  jflte  GT-I9505
# ...

# %%
all_data.shape
# Out:
# (201, 13)

# %%
all_data2 = pd.merge(us_us,us_dv,on="use_id",how='right').merge(an_dv, left_on="device", right_on= "Model", how='inner')

# %%
all_data2.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                      NaN                     NaN         NaN   22783
# 1                      NaN                     NaN         NaN   22784
# 2                   248.95                   52.47     1557.33   22971
# 3                   248.95                   52.47     1557.33   22972
# 4                      NaN                     NaN         NaN   22786
#
#    user_id platform  platform_version     device  use_type_id Retail Branding  \
# 0    29628  android               6.0    Nexus 5            3             LGE
# 1    28473  android               5.1   SM-G903F            1         Samsung
# 2    29696  android               5.1   SM-G903F            1         Samsung
# 3    29696  android               5.1   SM-G903F            1         Samsung
# 4    28239  android               6.0  ONE E1003            1         OnePlus
#
#   Marketing Name      Device      Model
# ...

# %%
all_data2.shape
# Out:
# (232, 13)

# %%
all_data3 = pd.merge(us_us,us_dv,on="use_id",how='left').merge(an_dv, left_on="device", right_on= "Model", how='inner')

# %%
all_data3.shape
# Out:
# (201, 13)

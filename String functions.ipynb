# %%
import os,numpy as np,pandas as pd

# %%
os.chdir("E:\\Machine learning course\\Raw data\\tableau")

# %%
Ecom = pd.read_excel("Ecommerce_data_p1vl9.xlsx")

# %%
pd.set_option("display.max_rows",30)
Ecom.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...   Product ID    Category Sub-Category  \
# ...

# %%
Ecom.shape
# Out:
# (51290, 24)

# %% [markdown]
# 1 lower
# 2 upper
# 3 capatalize
# 4 casehold
# 5 length
# 6 strip
# 7 split
# 8 cat
# 9 slice
# 10 contains
# 11 replace
# 12 repeat
# 13 count
# 14 startswith
# 15 endswith
# 16 find
# 17 swapcase
# 18 islower
# 19 isupper
# 20 isnumeric
# 21 isdigit

# %%
Ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   Postal Code     9994 non-null   float64
#  9   City            51290 non-null  object
#  10  State           51290 non-null  object
#  11  Country         51290 non-null  object
#  12  Region          51290 non-null  object
#  13  Market          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %%
Ecom.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %% [markdown]
# ## Lower - it converts strings in the Series to lower case

# %%
Ecom["Lower_City"]= Ecom.City.str.lower()

# %%
Ecom[['City','Lower_City']].tail()
# Out:
#                 City     Lower_City
# 51285           Kure           kure
# 51286    Chattanooga    chattanooga
# 51287  San Francisco  san francisco
# 51288       Valinhos       valinhos
# 51289       Tipitapa       tipitapa

# %%
pd.set_option("display.max_columns",100)
Ecom.head(3)
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
#
#     Customer ID  Customer Name    Segment  Postal Code           City  \
# 0  AB-100151402  Aaron Bergman   Consumer      73120.0  Oklahoma City
# 1     JR-162107  Justin Ritter  Corporate          NaN     Wollongong
# 2     CR-127307   Craig Reiter   Consumer          NaN       Brisbane
#
#              State        Country      Region        Market   Product ID  \
# 0         Oklahoma  United States  Central US          USCA  TEC-PH-5816
# 1  New South Wales      Australia     Oceania  Asia Pacific  FUR-CH-5379
# 2       Queensland      Australia     Oceania  Asia Pacific  TEC-PH-5356
#
#      Category Sub-Category                               Product Name  \
# ...

# %% [markdown]
# ## Upper- it converts strings in the series to upper case.

# %%
Ecom["Cu_Na"] = Ecom["Customer Name"].str.upper()

# %%
Ecom[["Customer Name","Cu_Na"]].head()
# Out:
#       Customer Name             Cu_Na
# 0     Aaron Bergman     AARON BERGMAN
# 1     Justin Ritter     JUSTIN RITTER
# 2      Craig Reiter      CRAIG REITER
# 3  Katherine Murray  KATHERINE MURRAY
# 4       Rick Hansen       RICK HANSEN

# %%
pd.set_option("display.max_columns",100)
Ecom.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#              State        Country          Region        Market   Product ID  \
# ...

# %% [markdown]
# ## capitalize - It converts first character to uppercase and remaining to lowercase

# %%
Ecom["Cu_Na"].head()
# Out:
# 0       AARON BERGMAN
# 1       JUSTIN RITTER
# 2        CRAIG REITER
# 3    KATHERINE MURRAY
# 4         RICK HANSEN
# Name: Cu_Na, dtype: object

# %%
Ecom["Customer_Capitalize"] = Ecom["Cu_Na"].str.capitalize()

# %%
Ecom[["Customer Name","Cu_Na","Customer_Capitalize"]].head()
# Out:
#       Customer Name             Cu_Na Customer_Capitalize
# 0     Aaron Bergman     AARON BERGMAN       Aaron bergman
# 1     Justin Ritter     JUSTIN RITTER       Justin ritter
# 2      Craig Reiter      CRAIG REITER        Craig reiter
# 3  Katherine Murray  KATHERINE MURRAY    Katherine murray
# 4       Rick Hansen       RICK HANSEN         Rick hansen

# %%
pd.set_option("display.max_columns",100)
Ecom.head(3)
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
#
#     Customer ID  Customer Name    Segment  Postal Code           City  \
# 0  AB-100151402  Aaron Bergman   Consumer      73120.0  Oklahoma City
# 1     JR-162107  Justin Ritter  Corporate          NaN     Wollongong
# 2     CR-127307   Craig Reiter   Consumer          NaN       Brisbane
#
#              State        Country      Region        Market   Product ID  \
# 0         Oklahoma  United States  Central US          USCA  TEC-PH-5816
# 1  New South Wales      Australia     Oceania  Asia Pacific  FUR-CH-5379
# 2       Queensland      Australia     Oceania  Asia Pacific  TEC-PH-5356
#
#      Category Sub-Category                               Product Name  \
# ...

# %% [markdown]
# ## casefold - Removes all case distinctions in the string.

# %%
Ecom["Casefold"] = Ecom["City"].str.casefold()

# %%
Ecom[["City","Casefold"]].head()
# Out:
#             City       Casefold
# 0  Oklahoma City  oklahoma city
# 1     Wollongong     wollongong
# 2       Brisbane       brisbane
# 3         Berlin         berlin
# 4          Dakar          dakar

# %%
pd.set_option("display.max_columns",100)
Ecom.head(2)
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
#
#     Customer ID  Customer Name    Segment  Postal Code           City  \
# 0  AB-100151402  Aaron Bergman   Consumer      73120.0  Oklahoma City
# 1     JR-162107  Justin Ritter  Corporate          NaN     Wollongong
#
#              State        Country      Region        Market   Product ID  \
# 0         Oklahoma  United States  Central US          USCA  TEC-PH-5816
# 1  New South Wales      Australia     Oceania  Asia Pacific  FUR-CH-5379
#
#      Category Sub-Category                               Product Name  \
# 0  Technology       Phones                           Samsung Convoy 3
# 1   Furniture       Chairs  Novimex Executive Leather Armchair, Black
#
#       Sales  Quantity  Discount    Profit  Shipping Cost Order Priority  \
# ...

# %% [markdown]
# ## Length - It gives the  string length

# %%
Ecom["Length_Name"] = Ecom["Customer Name"].str.len()

# %%
Ecom[["Customer Name","Length_Name"]].tail()
# Out:
#             Customer Name  Length_Name
# 51285     Katrina Edelman           15
# 51286  Zuschuss Donatelli           18
# 51287  Zuschuss Donatelli           18
# 51288          Ross Baird           10
# 51289       Mick Crebagga           13

# %% [markdown]
# ##  split- It splits the string in the Series

# %%
Ecom["split"] = Ecom["Order ID"].str.split('-')

# %%
Ecom["split"].head()
# Out:
# 0    [CA, 2014, AB10015140, 41954]
# 1      [IN, 2014, JR162107, 41675]
# 2      [IN, 2014, CR127307, 41929]
# 3     [ES, 2014, KM1637548, 41667]
# 4     [SG, 2014, RH9495111, 41948]
# Name: split, dtype: object

# %%
pd.set_option("display.max_columns",100)
Ecom.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#              State        Country          Region        Market   Product ID  \
# ...

# %% [markdown]
# ##  Cat - It is used to concatenate strings

# %%
new = Ecom["Ship Mode"]

# %%
Ecom["Cat_Name"]= Ecom["Customer Name"].str.cat(new, sep =", ")

# %%
Ecom["Cat_Name"].head()
# Out:
# 0       Aaron Bergman, First Class
# 1      Justin Ritter, Second Class
# 2        Craig Reiter, First Class
# 3    Katherine Murray, First Class
# 4            Rick Hansen, Same Day
# Name: Cat_Name, dtype: object

# %% [markdown]
#  ## slice- It  returns a slice object

# %%
Ecom[0:1]
# Out:
#    Row ID                  Order ID Order Date  Ship Date    Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13  First Class
#
#     Customer ID  Customer Name   Segment  Postal Code           City  ...  \
# 0  AB-100151402  Aaron Bergman  Consumer      73120.0  Oklahoma City  ...
#
#     Profit Shipping Cost Order Priority     Lower_City          Cu_Na  \
# 0  62.1544         40.77           High  oklahoma city  AARON BERGMAN
#
#   Customer_Capitalize       Casefold Length_Name  \
# 0       Aaron bergman  oklahoma city          13
#
#                            split                    Cat_Name
# 0  [CA, 2014, AB10015140, 41954]  Aaron Bergman, First Class
#
# [1 rows x 31 columns]

# %%
Ecom[0:10]
# Out:
#    Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# 5   22732    IN-2014-JM156557-41818 2014-06-28 2014-07-01    Second Class
# 6   30570   IN-2012-TS2134092-41219 2012-11-06 2012-11-08     First Class
# 7   31192   IN-2013-MB1808592-41378 2013-04-14 2013-04-18  Standard Class
# 8   40099  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 9   36258  CA-2012-AB10015140-40974 2012-03-06 2012-03-07     First Class
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# ...

# %%
Ecom[2:4]
# Out:
#    Row ID                 Order ID Order Date  Ship Date    Ship Mode  \
# 2   25330   IN-2014-CR127307-41929 2014-10-17 2014-10-18  First Class
# 3   13524  ES-2014-KM1637548-41667 2014-01-28 2014-01-30  First Class
#
#   Customer ID     Customer Name      Segment  Postal Code      City  ...  \
# 2   CR-127307      Craig Reiter     Consumer          NaN  Brisbane  ...
# 3  KM-1637548  Katherine Murray  Home Office          NaN    Berlin  ...
#
#     Profit Shipping Cost Order Priority Lower_City             Cu_Na  \
# 2  919.971        915.49         Medium   brisbane      CRAIG REITER
# 3  -96.540        910.16         Medium     berlin  KATHERINE MURRAY
#
#   Customer_Capitalize  Casefold Length_Name                         split  \
# 2        Craig reiter  brisbane          12   [IN, 2014, CR127307, 41929]
# 3    Katherine murray    berlin          16  [ES, 2014, KM1637548, 41667]
#
#                         Cat_Name
# 2      Craig Reiter, First Class
# ...

# %% [markdown]
# ## Replace - old string replace with new string which have given

# %%
Ecom['Order ID2'] = Ecom['Order ID'].str.replace('CA','XY')

# %%
Ecom['Order ID2'].head()
# Out:
# 0    XY-2014-AB10015140-41954
# 1      IN-2014-JR162107-41675
# 2      IN-2014-CR127307-41929
# 3     ES-2014-KM1637548-41667
# 4     SG-2014-RH9495111-41948
# Name: Order ID2, dtype: object

# %% [markdown]
# ## Repeat -It will repeat or replicate the rows of dataframe

# %%
Ecom["Repeat"]= Ecom["Segment"].str.repeat(2)

# %%
Ecom["Repeat"]
# Out:
# 0              ConsumerConsumer
# 1            CorporateCorporate
# 2              ConsumerConsumer
# 3        Home OfficeHome Office
# 4              ConsumerConsumer
#                   ...
# 51285        CorporateCorporate
# 51286          ConsumerConsumer
# 51287          ConsumerConsumer
# 51288    Home OfficeHome Office
# 51289          ConsumerConsumer
# Name: Repeat, Length: 51290, dtype: object

# %% [markdown]
# ## Contains-it is contained within a string of a series

# %%
Ecom["contains"] = Ecom["Ship Mode"].str.contains('First Class')

# %%
Ecom["contains"]
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Name: contains, Length: 51290, dtype: bool

# %%
Ecom["contains"].value_counts()
# Out:
# False    43785
# True      7505
# Name: contains, dtype: int64

# %% [markdown]
# ## Startswith

# %%
Ecom[Ecom["Order ID"].str.startswith('CA')].head(20)
# Out:
#     Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0    40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 8    40099  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 9    36258  CA-2012-AB10015140-40974 2012-03-06 2012-03-07     First Class
# 10   36259  CA-2012-AB10015140-40974 2012-03-06 2012-03-07     First Class
# 16   39519  CA-2012-AB10015140-40958 2012-02-19 2012-02-25  Standard Class
# 21   36260  CA-2012-AB10015140-40974 2012-03-06 2012-03-07     First Class
# 28   38460  CA-2012-AH10030140-41020 2012-04-21 2012-04-23    Second Class
# 32   40977  CA-2013-AH10030140-41635 2013-12-27 2013-12-31  Standard Class
# 34   40976  CA-2013-AH10030140-41635 2013-12-27 2013-12-31  Standard Class
# 36   36651  CA-2012-AH10030140-41041 2012-05-12 2012-05-18  Standard Class
# 37   40100  CA-2012-AH10030140-41273 2012-12-30 2012-12-31     First Class
# ...

# %% [markdown]
# ## Endswith

# %%
Ecom[Ecom["Customer Name"].str.endswith('a')].head(20)
# Out:
#       Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 39     28046    IN-2012-DL128657-40918 2012-01-10 2012-01-11     First Class
# 157     6449   MX-2015-DM1295551-42103 2015-04-09 2015-04-13  Standard Class
# 235     2080   MX-2012-MD1735028-41222 2012-11-09 2012-11-14    Second Class
# 262    20610   IN-2015-HA1492027-42111 2015-04-17 2015-04-17        Same Day
# 351    18691   ES-2014-DM1295545-42004 2014-12-31 2015-01-02     First Class
# 503    24435  ID-2015-KH16510102-42052 2015-02-17 2015-02-18     First Class
# 591    48487   RS-2012-JK5730108-41150 2012-08-29 2012-08-29        Same Day
# 819    17274  ES-2014-VP21760120-41990 2014-12-17 2014-12-17        Same Day
# 832    13967   ES-2013-CC1267064-41534 2013-09-17 2013-09-19     First Class
# 940    50372   RS-2012-GZ4545108-41088 2012-06-28 2012-07-03  Standard Class
# 1011    1320   MX-2014-KA1652539-41922 2014-10-10 2014-10-12     First Class
# ...

# %% [markdown]
# ## Find - It is used to search a substring in each string present in a series (position of value-1)

# %%
Ecom["Find"]= Ecom["Country"].str.find('i')

# %%
Ecom[["Country","Find"]].head()
# Out:
#          Country  Find
# 0  United States     2
# 1      Australia     7
# 2      Australia     7
# 3        Germany    -1
# 4        Senegal    -1

# %% [markdown]
# ## swapcase-lower case characters will be converted into uppercase and uppercase character into lower case in every string.

# %%
Ecom["Swap"] = Ecom["Market"].str.swapcase()

# %%
Ecom[["Market","Swap"]].head(10)
# Out:
#          Market          Swap
# 0          USCA          usca
# 1  Asia Pacific  aSIA pACIFIC
# 2  Asia Pacific  aSIA pACIFIC
# 3        Europe        eUROPE
# 4        Africa        aFRICA
# 5  Asia Pacific  aSIA pACIFIC
# 6  Asia Pacific  aSIA pACIFIC
# 7  Asia Pacific  aSIA pACIFIC
# 8          USCA          usca
# 9          USCA          usca

# %% [markdown]
# ## islower-If all characters in the string are lowercase

# %%
Ecom["islower"] = Ecom["Segment"].str.islower()

# %%
Ecom[["Segment","islower"]].head(10)
# Out:
#        Segment  islower
# 0     Consumer    False
# 1    Corporate    False
# 2     Consumer    False
# 3  Home Office    False
# 4     Consumer    False
# 5    Corporate    False
# 6     Consumer    False
# 7     Consumer    False
# 8     Consumer    False
# 9     Consumer    False

# %% [markdown]
# ## isupper-If all characters in the string are uppercase

# %%
Ecom["isupper"] = Ecom["Market"].str.isupper()

# %%
Ecom[["isupper" ,"Market"]].head(10)
# Out:
#    isupper        Market
# 0     True          USCA
# 1    False  Asia Pacific
# 2    False  Asia Pacific
# 3    False        Europe
# 4    False        Africa
# 5    False  Asia Pacific
# 6    False  Asia Pacific
# 7    False  Asia Pacific
# 8     True          USCA
# 9     True          USCA

# %% [markdown]
# ## isnumeric -  It returns true if all characters in a string are numeric characters. If not, it returns False

# %%
Ecom["isnumeric"] = Ecom["Customer ID"].str.isnumeric()

# %%
Ecom[["Customer ID","isnumeric"]].head()
# Out:
#     Customer ID  isnumeric
# 0  AB-100151402      False
# 1     JR-162107      False
# 2     CR-127307      False
# 3    KM-1637548      False
# 4    RH-9495111      False
